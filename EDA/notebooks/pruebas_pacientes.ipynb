# %%
import pandas as pd 
import numpy as np

# %%
pacientes_bruto = pd.read_csv("D:\MAURO\CURSOS\Master_The_Bridge\Bridge_Python\MGOL_BOOTCAMP\proyecto2\EDA\data\LUNG_PATIENT_DATA.tsv", sep='\t')
pacientes_bruto.set_index('track_name', inplace=True)
pacientes_bruto.drop(['track_type'], axis=1, inplace = True)
pacientes_bruto
pacientes_select = pacientes_bruto.loc[['Sex', 'Diagnosis Age', 'Progress Free Survival (Months)', 'Ethnicity Category', 'Mutation Count']]
pacientes_select
# Out:
#                                  TCGA-55-8302            TCGA-55-8094  \
# track_name
# Sex                                      Male                    Male
# Diagnosis Age                              54                      51
# Progress Free Survival (Months)  15.714896275      17.786106454000002
# Ethnicity Category                        NaN  Not Hispanic Or Latino
# Mutation Count                            615                     395
#
#                                            TCGA-99-8033  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        74
# Progress Free Survival (Months)      21.566886938000003
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      168
#
#                                            TCGA-69-7978  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        59
# Progress Free Survival (Months)       4.405431173399999
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      546
#
#                                            TCGA-86-A4JF  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        56
# Progress Free Survival (Months)            14.334089489
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                     1228
#
#                                            TCGA-44-8117  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        54
# Progress Free Survival (Months)            12.657395535
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      679
#
#                                            TCGA-55-6975 TCGA-17-Z050  \
# track_name
# Sex                                                Male          NaN
# Diagnosis Age                                        61          NaN
# Progress Free Survival (Months)      3.8794095406999998          NaN
# Ethnicity Category               Not Hispanic Or Latino          NaN
# Mutation Count                                       85          167
#
#                                            TCGA-55-7576  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        54
# Progress Free Survival (Months)      22.027155866999998
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      371
#
#                                            TCGA-91-6836  ... luad_tsp_16973  \
# track_name                                               ...
# Sex                                              Female  ...            NaN
# Diagnosis Age                                        52  ...            NaN
# Progress Free Survival (Months)            13.709438801  ...            NaN
# Ethnicity Category               Not Hispanic Or Latino  ...            NaN
# Mutation Count                                      457  ...              3
#
#                                 luad_tsp_16993 luad_tsp_17156 luad_tsp_17194  \
# track_name
# Sex                                        NaN            NaN            NaN
# Diagnosis Age                              NaN            NaN            NaN
# Progress Free Survival (Months)            NaN            NaN            NaN
# Ethnicity Category                         NaN            NaN            NaN
# Mutation Count                               2             10              2
#
#                                 luad_tsp_17258 luad_tsp_17326 luad_tsp_17730  \
# track_name
# Sex                                        NaN            NaN            NaN
# Diagnosis Age                              NaN            NaN            NaN
# Progress Free Survival (Months)            NaN            NaN            NaN
# Ethnicity Category                         NaN            NaN            NaN
# Mutation Count                               2              2              6
#
#                                 luad_tsp_17745 luad_tsp_17769 luad_tsp_17784
# track_name
# Sex                                        NaN            NaN            NaN
# Diagnosis Age                              NaN            NaN            NaN
# Progress Free Survival (Months)            NaN            NaN            NaN
# Ethnicity Category                         NaN            NaN            NaN
# Mutation Count                               1              2              5
#
# [5 rows x 912 columns]

# %%
pacientes_select = pacientes_bruto.loc[['Sex', 'Diagnosis Age', 'Progress Free Survival (Months)', 'Ethnicity Category', 'Mutation Count']]
pacientes_select
# Out:
#                                  TCGA-55-8302            TCGA-55-8094  \
# track_name
# Sex                                      Male                    Male
# Diagnosis Age                              54                      51
# Progress Free Survival (Months)  15.714896275      17.786106454000002
# Ethnicity Category                        NaN  Not Hispanic Or Latino
# Mutation Count                            615                     395
#
#                                            TCGA-99-8033  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        74
# Progress Free Survival (Months)      21.566886938000003
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      168
#
#                                            TCGA-69-7978  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        59
# Progress Free Survival (Months)       4.405431173399999
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      546
#
#                                            TCGA-86-A4JF  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        56
# Progress Free Survival (Months)            14.334089489
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                     1228
#
#                                            TCGA-44-8117  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        54
# Progress Free Survival (Months)            12.657395535
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      679
#
#                                            TCGA-55-6975 TCGA-17-Z050  \
# track_name
# Sex                                                Male          NaN
# Diagnosis Age                                        61          NaN
# Progress Free Survival (Months)      3.8794095406999998          NaN
# Ethnicity Category               Not Hispanic Or Latino          NaN
# Mutation Count                                       85          167
#
#                                            TCGA-55-7576  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        54
# Progress Free Survival (Months)      22.027155866999998
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      371
#
#                                            TCGA-91-6836  ... luad_tsp_16973  \
# track_name                                               ...
# Sex                                              Female  ...            NaN
# Diagnosis Age                                        52  ...            NaN
# Progress Free Survival (Months)            13.709438801  ...            NaN
# Ethnicity Category               Not Hispanic Or Latino  ...            NaN
# Mutation Count                                      457  ...              3
#
#                                 luad_tsp_16993 luad_tsp_17156 luad_tsp_17194  \
# track_name
# Sex                                        NaN            NaN            NaN
# Diagnosis Age                              NaN            NaN            NaN
# Progress Free Survival (Months)            NaN            NaN            NaN
# Ethnicity Category                         NaN            NaN            NaN
# Mutation Count                               2             10              2
#
#                                 luad_tsp_17258 luad_tsp_17326 luad_tsp_17730  \
# track_name
# Sex                                        NaN            NaN            NaN
# Diagnosis Age                              NaN            NaN            NaN
# Progress Free Survival (Months)            NaN            NaN            NaN
# Ethnicity Category                         NaN            NaN            NaN
# Mutation Count                               2              2              6
#
#                                 luad_tsp_17745 luad_tsp_17769 luad_tsp_17784
# track_name
# Sex                                        NaN            NaN            NaN
# Diagnosis Age                              NaN            NaN            NaN
# Progress Free Survival (Months)            NaN            NaN            NaN
# Ethnicity Category                         NaN            NaN            NaN
# Mutation Count                               1              2              5
#
# [5 rows x 912 columns]

# %%
pacientes_select = pacientes_select.dropna(axis=1, how='any')
pacientes_select
# Out:
#                                            TCGA-55-8094  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        51
# Progress Free Survival (Months)      17.786106454000002
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      395
#
#                                            TCGA-99-8033  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        74
# Progress Free Survival (Months)      21.566886938000003
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      168
#
#                                            TCGA-69-7978  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        59
# Progress Free Survival (Months)       4.405431173399999
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      546
#
#                                            TCGA-86-A4JF  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        56
# Progress Free Survival (Months)            14.334089489
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                     1228
#
#                                            TCGA-44-8117  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        54
# Progress Free Survival (Months)            12.657395535
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      679
#
#                                            TCGA-55-6975  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        61
# Progress Free Survival (Months)      3.8794095406999998
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                       85
#
#                                            TCGA-55-7576  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        54
# Progress Free Survival (Months)      22.027155866999998
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      371
#
#                                            TCGA-91-6836 LUAD-B00523  \
# track_name
# Sex                                              Female        Male
# Diagnosis Age                                        52          68
# Progress Free Survival (Months)            13.709438801        13.6
# Ethnicity Category               Not Hispanic Or Latino    European
# Mutation Count                                      457         440
#
#                                 LUAD-E00443  ...            TCGA-91-8497  \
# track_name                                   ...
# Sex                                    Male  ...                  Female
# Diagnosis Age                            74  ...                      75
# Progress Free Survival (Months)       21.27  ...            14.268336785
# Ethnicity Category                 European  ...  Not Hispanic Or Latino
# Mutation Count                          425  ...                      40
#
#                                            TCGA-93-A4JQ  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        49
# Progress Free Survival (Months)            17.292961173
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      104
#
#                                            TCGA-93-7348  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        75
# Progress Free Survival (Months)            17.457342933
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      103
#
#                                            TCGA-95-7948  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        42
# Progress Free Survival (Months)            15.649143571
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      142
#
#                                            TCGA-97-A4M2  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        66
# Progress Free Survival (Months)      20.514843672999998
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                       26
#
#                                            TCGA-97-7546  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        76
# Progress Free Survival (Months)             41.25982181
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      252
#
#                                            TCGA-97-7547  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        67
# Progress Free Survival (Months)            25.479172831
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      158
#
#                                            TCGA-97-7552  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        70
# Progress Free Survival (Months)            26.235328928
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                       35
#
#                                            TCGA-97-8174  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        67
# Progress Free Survival (Months)       5.391721734600001
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                      158
#
#                                            TCGA-99-AA5R
# track_name
# Sex                                              Female
# Diagnosis Age                                        70
# Progress Free Survival (Months)      21.632639641999997
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                       54
#
# [5 rows x 520 columns]

# %%
pacientes_Lung = pacientes_select.T
pacientes_Lung
# Out:
# track_name       Sex Diagnosis Age Progress Free Survival (Months)  \
# TCGA-55-8094    Male            51              17.786106454000002
# TCGA-99-8033  Female            74              21.566886938000003
# TCGA-69-7978    Male            59               4.405431173399999
# TCGA-86-A4JF    Male            56                    14.334089489
# TCGA-44-8117  Female            54                    12.657395535
# ...              ...           ...                             ...
# TCGA-97-7546  Female            76                     41.25982181
# TCGA-97-7547  Female            67                    25.479172831
# TCGA-97-7552    Male            70                    26.235328928
# TCGA-97-8174    Male            67               5.391721734600001
# TCGA-99-AA5R  Female            70              21.632639641999997
#
# track_name        Ethnicity Category Mutation Count
# TCGA-55-8094  Not Hispanic Or Latino            395
# TCGA-99-8033  Not Hispanic Or Latino            168
# TCGA-69-7978  Not Hispanic Or Latino            546
# TCGA-86-A4JF  Not Hispanic Or Latino           1228
# TCGA-44-8117  Not Hispanic Or Latino            679
# ...                              ...            ...
# TCGA-97-7546  Not Hispanic Or Latino            252
# TCGA-97-7547  Not Hispanic Or Latino            158
# TCGA-97-7552  Not Hispanic Or Latino             35
# TCGA-97-8174  Not Hispanic Or Latino            158
# TCGA-99-AA5R  Not Hispanic Or Latino             54
#
# [520 rows x 5 columns]

# %%
pacientes_bruto = pd.read_csv("D:\MAURO\CURSOS\Master_The_Bridge\Bridge_Python\MGOL_BOOTCAMP\proyecto2\EDA\data\pancreas_PATIENT_DATA_oncoprint.tsv", sep='\t')
pacientes_bruto.set_index('track_name', inplace=True)
pacientes_bruto.drop(['track_type'], axis=1, inplace = True)
pacientes_bruto
pacientes_select = pacientes_bruto.loc[['Sex', 'Diagnosis Age', 'Progress Free Survival (Months)', 'Ethnicity Category', 'Mutation Count']]
pacientes_select
# Out:
#                                 PDA_074            TCGA-IB-7886 ICGC_0135  \
# track_name
# Sex                                Male                    Male    Female
# Diagnosis Age                        63                      80        62
# Progress Free Survival (Months)     NaN            4.0437913009       NaN
# Ethnicity Category                  NaN  Not Hispanic Or Latino     Asian
# Mutation Count                      398                      41        44
#
#                                      ICGC_0185        ICGC_0245  \
# track_name
# Sex                                     Female           Female
# Diagnosis Age                               61               67
# Progress Free Survival (Months)            NaN              NaN
# Ethnicity Category               Black/African  White/Caucasian
# Mutation Count                              26               42
#
#                                               ICGC_0415 PDA_048 PDA_060  \
# track_name
# Sex                                              Female  Female  Female
# Diagnosis Age                                        55      66      48
# Progress Free Survival (Months)                     NaN     NaN     NaN
# Ethnicity Category               Asian, White/Caucasian     NaN     NaN
# Mutation Count                                       35      47      87
#
#                                 PDA_084  TCGA-2J-AAB8  ... PCSI0047 PCSI0048  \
# track_name                                             ...
# Sex                                Male          Male  ...     Male     Male
# Diagnosis Age                        85            71  ...       55       76
# Progress Free Survival (Months)     NaN  2.6301081632  ...      NaN      NaN
# Ethnicity Category                  NaN           NaN  ...      NaN      NaN
# Mutation Count                      106            43  ...        0        0
#
#                                 PCSI0072 PCSI0073            TCGA-F2-7276  \
# track_name
# Sex                                 Male     Male                    Male
# Diagnosis Age                         83       69                      64
# Progress Free Survival (Months)      NaN      NaN            7.1012920406
# Ethnicity Category                   NaN      NaN  Not Hispanic Or Latino
# Mutation Count                         0        0                       0
#
#                                            TCGA-HZ-7923  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        65
# Progress Free Survival (Months)            10.323174541
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                        0
#
#                                            TCGA-HZ-8519  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        73
# Progress Free Survival (Months)      14.925863825999999
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                        0
#
#                                            TCGA-IB-AAUT  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        65
# Progress Free Survival (Months)            9.4355130355
# Ethnicity Category               Not Hispanic Or Latino
# Mutation Count                                        0
#
#                                            TCGA-US-A77J TS-0111
# track_name
# Sex                                              Female  Female
# Diagnosis Age                                        81      53
# Progress Free Survival (Months)            18.673767959     NaN
# Ethnicity Category               Not Hispanic Or Latino     NaN
# Mutation Count                                        0       0
#
# [5 rows x 749 columns]

# %%
pacientes_bruto = pd.read_csv("D:\MAURO\CURSOS\Master_The_Bridge\Bridge_Python\MGOL_BOOTCAMP\proyecto2\EDA\data\glioblastoma_PATIENT_DATA_oncoprint.tsv", sep='\t')
pacientes_bruto.set_index('track_name', inplace=True)
pacientes_bruto.drop(['track_type'], axis=1, inplace = True)
pacientes_bruto
pacientes_select = pacientes_bruto.loc[['Sex', 'Diagnosis Age', 'Progress Free Survival (Months)', 'Ethnicity Category', 'Mutation Count']]
pacientes_select
# Out:
#                                            TCGA-16-0846  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        85
# Progress Free Survival (Months)                     NaN
# Ethnicity Category               NOT HISPANIC OR LATINO
# Mutation Count                                       65
#
#                                            TCGA-06-0646  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        60
# Progress Free Survival (Months)                     NaN
# Ethnicity Category               NOT HISPANIC OR LATINO
# Mutation Count                                       41
#
#                                            TCGA-06-0192  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        58
# Progress Free Survival (Months)                     NaN
# Ethnicity Category               NOT HISPANIC OR LATINO
# Mutation Count                                       61
#
#                                            TCGA-06-0213  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        55
# Progress Free Survival (Months)                     NaN
# Ethnicity Category               NOT HISPANIC OR LATINO
# Mutation Count                                       57
#
#                                            TCGA-41-2573  \
# track_name
# Sex                                                Male
# Diagnosis Age                                        59
# Progress Free Survival (Months)                     NaN
# Ethnicity Category               NOT HISPANIC OR LATINO
# Mutation Count                                       44
#
#                                            TCGA-12-3646  \
# track_name
# Sex                                              Female
# Diagnosis Age                                        59
# Progress Free Survival (Months)                     NaN
# Ethnicity Category               NOT HISPANIC OR LATINO
# Mutation Count                                        0
#
#                                            TCGA-14-1825 gbm_columbia_2019_55  \
# track_name
# Sex                                                Male                 Male
# Diagnosis Age                                        70                  NaN
# Progress Free Survival (Months)                     NaN          34.40958904
# Ethnicity Category               NOT HISPANIC OR LATINO                  NaN
# Mutation Count                                       47                   82
#
#                                 TCGA-14-0813            TCGA-27-2519  ...  \
# track_name                                                            ...
# Sex                                     Male                    Male  ...
# Diagnosis Age                             78                      48  ...
# Progress Free Survival (Months)          NaN                     NaN  ...
# Ethnicity Category                       NaN  NOT HISPANIC OR LATINO  ...
# Mutation Count                            86                      50  ...
#
#                                 gbm_columbia_2019_NU_1 gbm_columbia_2019_NU_4  \
# track_name
# Sex                                               Male                   Male
# Diagnosis Age                                      NaN                    NaN
# Progress Free Survival (Months)                  10.76                   9.88
# Ethnicity Category                                 NaN                    NaN
# Mutation Count                                       0                      0
#
#                                 gbm_columbia_2019_NU_5 gbm_columbia_2019_NU_7  \
# track_name
# Sex                                               Male                   Male
# Diagnosis Age                                      NaN                    NaN
# Progress Free Survival (Months)                  11.39                  22.91
# Ethnicity Category                                 NaN                    NaN
# Mutation Count                                       0                      0
#
#                                 gbm_columbia_2019_NU_8  \
# track_name
# Sex                                             Female
# Diagnosis Age                                      NaN
# Progress Free Survival (Months)                  19.49
# Ethnicity Category                                 NaN
# Mutation Count                                       0
#
#                                 gbm_columbia_2019_NU_12  \
# track_name
# Sex                                              Female
# Diagnosis Age                                       NaN
# Progress Free Survival (Months)                     NaN
# Ethnicity Category                                  NaN
# Mutation Count                                        0
#
#                                 gbm_columbia_2019_NU_13  \
# track_name
# Sex                                                Male
# Diagnosis Age                                       NaN
# Progress Free Survival (Months)                   29.77
# Ethnicity Category                                  NaN
# Mutation Count                                        0
#
#                                 gbm_columbia_2019_NU_14  \
# track_name
# Sex                                              Female
# Diagnosis Age                                       NaN
# Progress Free Survival (Months)                    9.92
# Ethnicity Category                                  NaN
# Mutation Count                                        0
#
#                                 gbm_columbia_2019_NU_16  \
# track_name
# Sex                                                Male
# Diagnosis Age                                       NaN
# Progress Free Survival (Months)                    9.49
# Ethnicity Category                                  NaN
# Mutation Count                                        0
#
#                                 gbm_columbia_2019_NU_20
# track_name
# Sex                                                Male
# Diagnosis Age                                       NaN
# Progress Free Survival (Months)                    5.85
# Ethnicity Category                                  NaN
# Mutation Count                                        0
#
# [5 rows x 730 columns]
