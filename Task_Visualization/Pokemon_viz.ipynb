# %% [markdown]
# # Pokemon **

# %% [markdown]
# ### Step 1. Importa las librerías necesarias

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %% [markdown]
# ### Step 2. Activa matplotlib de forma estática

# %%
#no se que significa esto

# %% [markdown]
# ### Step 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
address = "D:\MAURO\CURSOS\Master_The_Bridge\Bridge_Python\MGOL_BOOTCAMP\Task_Visualization\data\Pokemon.csv"
poke = pd.read_csv(address)

# %% [markdown]
# ### Step 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
poke.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %% [markdown]
# ### Step 5. Haz un scatter plot con `lmplot()`, que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado `data`

# %%
data = sns.lmplot(x="Defense", y="Attack", data=poke)

# %% [markdown]
# ### Step 6. No queremos ver la línea recta de la regresión lineal.
# Prueba a añadir fit_reg a falso

# %%
data = sns.lmplot(x="Defense", y="Attack", data=poke, fit_reg = False)

# %% [markdown]
# ### Step 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el `hue` sea el Stage

# %%
data = sns.lmplot(x="Defense", y="Attack", data=poke, fit_reg = False, hue= 'Stage')

# %% [markdown]
# ### Step 8. Limita el eje x entre 20 y 100

# %%
#no he encontrado como hacer esto

# %% [markdown]
# ### Step 9. Dibuja un diagrama de cajas con el dataframe

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data = poke)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
poke.drop(['#', 'Total', 'Stage', 'Legendary'], axis=1, inplace=True)

# %%
poke
# Out:
#            Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0     Bulbasaur    Grass  Poison   45      49       49       65       65
# 1       Ivysaur    Grass  Poison   60      62       63       80       80
# 2      Venusaur    Grass  Poison   80      82       83      100      100
# 3    Charmander     Fire     NaN   39      52       43       60       50
# 4    Charmeleon     Fire     NaN   58      64       58       80       65
# ..          ...      ...     ...  ...     ...      ...      ...      ...
# 146     Dratini   Dragon     NaN   41      64       45       50       50
# 147   Dragonair   Dragon     NaN   61      84       65       70       70
# 148   Dragonite   Dragon  Flying   91     134       95      100      100
# 149      Mewtwo  Psychic     NaN  106     110       90      154       90
# 150         Mew  Psychic     NaN  100     100      100      100      100
#
#      Speed
# 0       45
# 1       60
# 2       80
# 3       65
# 4       80
# ..     ...
# 146     50
# 147     70
# 148     80
# 149    130
# 150    100
#
# [151 rows x 9 columns]

# %% [markdown]
# ### Step 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
poke.groupby('Type 1').count()
# Out:
#           Name  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Type 1
# Bug         12       9  12      12       12       12       12     12
# Dragon       3       1   3       3        3        3        3      3
# Electric     9       3   9       9        9        9        9      9
# Fairy        2       0   2       2        2        2        2      2
# Fighting     7       0   7       7        7        7        7      7
# Fire        12       2  12      12       12       12       12     12
# Ghost        3       3   3       3        3        3        3      3
# Grass       12      11  12      12       12       12       12     12
# Ground       8       2   8       8        8        8        8      8
# Ice          2       2   2       2        2        2        2      2
# Normal      22      10  22      22       22       22       22     22
# Poison      14       4  14      14       14       14       14     14
# Psychic      8       1   8       8        8        8        8      8
# Rock         9       9   9       9        9        9        9      9
# Water       28      10  28      28       28       28       28     28

# %%
poke['Type 1'].nunique()
# Out:
# 15

# %% [markdown]
# ### Step 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
poke.loc[poke['Type 1'].isin(['Grass', 'Fire', 'Water'])]
# Out:
#            Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0     Bulbasaur  Grass    Poison   45      49       49       65       65
# 1       Ivysaur  Grass    Poison   60      62       63       80       80
# 2      Venusaur  Grass    Poison   80      82       83      100      100
# 3    Charmander   Fire       NaN   39      52       43       60       50
# 4    Charmeleon   Fire       NaN   58      64       58       80       65
# 5     Charizard   Fire    Flying   78      84       78      109       85
# 6      Squirtle  Water       NaN   44      48       65       50       64
# 7     Wartortle  Water       NaN   59      63       80       65       80
# 8     Blastoise  Water       NaN   79      83      100       85      105
# 36       Vulpix   Fire       NaN   38      41       40       50       65
# 37    Ninetales   Fire       NaN   73      76       75       81      100
# 42       Oddish  Grass    Poison   45      50       55       75       65
# 43        Gloom  Grass    Poison   60      65       70       85       75
# 44    Vileplume  Grass    Poison   75      80       85      110       90
# 53      Psyduck  Water       NaN   50      52       48       65       50
# 54      Golduck  Water       NaN   80      82       78       95       80
# 57    Growlithe   Fire       NaN   55      70       45       70       50
# 58     Arcanine   Fire       NaN   90     110       80      100       80
# 59      Poliwag  Water       NaN   40      50       40       40       40
# 60    Poliwhirl  Water       NaN   65      65       65       50       50
# 61    Poliwrath  Water  Fighting   90      95       95       70       90
# 68   Bellsprout  Grass    Poison   50      75       35       70       30
# 69   Weepinbell  Grass    Poison   65      90       50       85       45
# 70   Victreebel  Grass    Poison   80     105       65      100       70
# 71    Tentacool  Water    Poison   40      40       35       50      100
# 72   Tentacruel  Water    Poison   80      70       65       80      120
# 76       Ponyta   Fire       NaN   50      85       55       65       65
# 77     Rapidash   Fire       NaN   65     100       70       80       80
# 78     Slowpoke  Water   Psychic   90      65       65       40       40
# 79      Slowbro  Water   Psychic   95      75      110      100       80
# 85         Seel  Water       NaN   65      45       55       45       70
# 86      Dewgong  Water       Ice   90      70       80       70       95
# 89     Shellder  Water       NaN   30      65      100       45       25
# 90     Cloyster  Water       Ice   50      95      180       85       45
# 97       Krabby  Water       NaN   30     105       90       25       25
# 98      Kingler  Water       NaN   55     130      115       50       50
# 101   Exeggcute  Grass   Psychic   60      40       80       60       45
# 102   Exeggutor  Grass   Psychic   95      95       85      125       65
# 113     Tangela  Grass       NaN   65      55      115      100       40
# 115      Horsea  Water       NaN   30      40       70       70       25
# 116      Seadra  Water       NaN   55      65       95       95       45
# 117     Goldeen  Water       NaN   45      67       60       35       50
# 118     Seaking  Water       NaN   80      92       65       65       80
# 119      Staryu  Water       NaN   30      45       55       70       55
# 120     Starmie  Water   Psychic   60      75       85      100       85
# 125      Magmar   Fire       NaN   65      95       57      100       85
# 128    Magikarp  Water       NaN   20      10       55       15       20
# 129    Gyarados  Water    Flying   95     125       79       60      100
# 130      Lapras  Water       Ice  130      85       80       85       95
# 133    Vaporeon  Water       NaN  130      65       60      110       95
# 135     Flareon   Fire       NaN   65     130       60       95      110
# 145     Moltres   Fire    Flying   90     100       90      125       85
#
#      Speed
# 0       45
# 1       60
# 2       80
# 3       65
# 4       80
# 5      100
# 6       43
# 7       58
# 8       78
# 36      65
# 37     100
# 42      30
# 43      40
# 44      50
# 53      55
# 54      85
# 57      60
# 58      95
# 59      90
# 60      90
# 61      70
# 68      40
# 69      55
# 70      70
# 71      70
# 72     100
# 76      90
# 77     105
# 78      15
# 79      30
# 85      45
# 86      70
# 89      40
# 90      70
# 97      50
# 98      75
# 101     40
# 102     55
# 113     60
# 115     60
# 116     85
# 117     63
# 118     68
# 119     85
# 120    115
# 125     93
# 128     80
# 129     81
# 130     60
# 133     65
# 135     65
# 145     90

# %% [markdown]
# ### Step 13. Usa un estilo 'whitegrid'

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.boxplot(data = poke)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 14. Pinta diagramas de violín con el DataFrame

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.violinplot(data = poke)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colors = ["#78C85", "#F08030", "#6890F0"]

# %% [markdown]
# ### Step 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.set_palette(sns.color_palette(colors))
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.violinplot(data = poke)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\palettes.py in color_palette(palette, n_colors, desat, as_cmap)
#     221             palette = map(mpl.colors.colorConverter.to_rgb, palette)
# --> 222             palette = _ColorPalette(palette)
#     223         except ValueError:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\colors.py in to_rgb(c)
#     393     """Convert *c* to an RGB color, silently dropping the alpha channel."""
# --> 394     return to_rgba(c)[:3]
#     395
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     205     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 206         rgba = _to_rgba_no_colorcycle(c, alpha)
#     207         try:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     276             return c, c, c, alpha if alpha is not None else 1.
# --> 277         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     278     # turn 2-D array into 1-D array
#
# ValueError: Invalid RGBA argument: '#78C85'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-2b8ad73de877> in <module>
# ----> 1 sns.set_palette(sns.color_palette(colors))
#       2 sns.set_style("whitegrid")
#       3 plt.figure(figsize=(10,5))
#       4 sns.violinplot(data = poke)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\palettes.py in color_palette(palette, n_colors, desat, as_cmap)
#     222             palette = _ColorPalette(palette)
#     223         except ValueError:
# --> 224             raise ValueError(f"Could not generate a palette for {palette}")
#     225
#     226     return palette
#
# ValueError: Could not generate a palette for <map object at 0x000001E6ACA59588>

# %% [markdown]
# ### Step 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# - Para ver esto, usamos el swarmplot.
# - Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.swarmplot(data = poke)
# Out:
# C:\Users\MAUCRO\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:>

# %% [markdown]
# ### Step 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos.
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.swarmplot(data = poke)
sns.violinplot(data = poke)
# Out:
# C:\Users\MAUCRO\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:>

# %% [markdown]
# ### Step 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
#  Dado un DataFrame, [melt](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.melt.html) recibe varios parámetros:
#  * qué columnas del DataFrame se quedan igual
#  * qué nombres de columnas del dataframe pasan a ser una columna nueva
#  * cómo queremos llamar esas nuevas columnas
#
# Primero recuerda el Dataframe `df_grass_fire_water` con las primeras 5 filas

# %% [markdown]
# ### Step 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
#
# Escribimos `df_grass_fire_water.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')`

# %%
# Out:
#          Name Type 1 Melted value
# 0   Bulbasaur  Grass     HP    45
# 1     Ivysaur  Grass     HP    60
# 2    Venusaur  Grass     HP    80
# 3  Charmander   Fire     HP    39
# 4  Charmeleon   Fire     HP    58

# %% [markdown]
# ### Step 21. Pintamos el swarmplot con el melted y entendemos la información

# %% [markdown]
# ### Step 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
#
# Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# Usando plt:
#   - fija el límite del eje Y entre 0 y 200
#   - fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %% [markdown]
# ### Step 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
#
# Las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(poke.corr(),
           vmin = -1,
           vmax = 1,
            annot = True,
           linewidths = .5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
plt.figure(figsize=(12,8))
sns.distplot(poke["Defense"], color = "skyblue", label = "Defense Level")
plt.legend()
# Out:
# C:\Users\MAUCRO\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Step 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot y plt.xticks para girar las etiquetas

# %%
plt.figure(figsize=(20,40))
sns.catplot(x ='Type 1',
           kind = 'count',
           edgecolor = ".6",
           data = poke)

# %% [markdown]
# ### Step 26. Usa catplot con el DataFrame original.
# Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendariosy divide los colores según el Type 2

# %% [markdown]
# ### Step 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.

# %% [markdown]
# ### Step 29. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original
