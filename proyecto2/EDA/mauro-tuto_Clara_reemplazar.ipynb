# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Samanosukeh/Analise-descritiva-de-dados-titanic/master/titanic.csv"

# %%
sea = pd.read_csv(url)

# %%
sea.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
listaletras = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J", "K", "L"]

# %%
dicti = {key:value for key, value in zip(sea.columns, listaletras)}
dicti
# Out:
# {'PassengerId': 'A',
#  'Survived': 'B',
#  'Pclass': 'C',
#  'Name': 'D',
#  'Sex': 'E',
#  'Age': 'F',
#  'SibSp': 'G',
#  'Parch': 'H',
#  'Ticket': 'I',
#  'Fare': 'J',
#  'Cabin': 'K',
#  'Embarked': 'L'}

# %%
# https://stackoverflow.com/questions/33218719/replace-non-null-values-in-column-by-1
def sustituir(df, diccionario):
    for col in df.columns:
        df.loc[df[col].notnull(), col] = diccionario[col]
    return df

# %%
sustituir(sea, dicti)
# Out:
#     PassengerId Survived Pclass Name Sex  Age SibSp Parch Ticket Fare Cabin  \
# 0             A        B      C    D   E    F     G     H      I    J   NaN
# 1             A        B      C    D   E    F     G     H      I    J     K
# 2             A        B      C    D   E    F     G     H      I    J   NaN
# 3             A        B      C    D   E    F     G     H      I    J     K
# 4             A        B      C    D   E    F     G     H      I    J   NaN
# ..          ...      ...    ...  ...  ..  ...   ...   ...    ...  ...   ...
# 886           A        B      C    D   E    F     G     H      I    J   NaN
# 887           A        B      C    D   E    F     G     H      I    J     K
# 888           A        B      C    D   E  NaN     G     H      I    J   NaN
# 889           A        B      C    D   E    F     G     H      I    J     K
# 890           A        B      C    D   E    F     G     H      I    J   NaN
#
#     Embarked
# 0          L
# 1          L
# ...
